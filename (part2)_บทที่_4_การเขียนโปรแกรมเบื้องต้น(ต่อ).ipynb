# %% [markdown]
# <a href="https://colab.research.google.com/github/artinuch/-iot/blob/main/(part2)_%E0%B8%9A%E0%B8%97%E0%B8%97%E0%B8%B5%E0%B9%88_4_%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B9%80%E0%B8%82%E0%B8%B5%E0%B8%A2%E0%B8%99%E0%B9%82%E0%B8%9B%E0%B8%A3%E0%B9%81%E0%B8%81%E0%B8%A3%E0%B8%A1%E0%B9%80%E0%B8%9A%E0%B8%B7%E0%B9%89%E0%B8%AD%E0%B8%87%E0%B8%95%E0%B9%89%E0%B8%99(%E0%B8%95%E0%B9%88%E0%B8%AD).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***หน่วย 4 การเขียนโปรแกรมเบื้องต้น (Part1)*** 🍵

# %% [markdown]
# **จัดทำโดยสื่อประกอบการสอนโดย ครูจิรายุส อรุณเดชาชัย  🧑**

# %% [markdown]
# ![2728cab18277ecc96049fc4e6bdb348f.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##📂 **เนื้อหา**
#
# 1.   ตัวแปลภาษา
# 2.   รู้จักกับภาษาไพทอน
# 3.   พื้นฐานการเขียนโปรแกรมด้วยภาษาไพทอน

# %% [markdown]
# ##🎯 จุดประสงค์การเรียนรู้
# 1.   เขียนโปรแกรมเพื่อรับและแสดงผลข้อมูลได้
# 2.   เลือกใช้ตัวดำเนินการได้อย่างถูกต้องและเหมาะสม
# 3.   เขียนโปรแกรมที่มีโครงสร้างการทำงานแบบลำดับได้
#
#
#
# ---

# %% [markdown]
# ## **💻 ตัวแปลภาษา (Compiler/Interpreter)**

# %% [markdown]
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# ✍ การเขียนโปรแกรมด้วยภาษาระดับสูง จะมีลักษณะของโครงสร้างภาษาแตกต่างกันออกไป ซึ่งโปรแกรมที่มนุษย์เขียนขึ้นมานั้น เรียกว่า โปรแกรมต้นฉบับ (Source Code)    มนุษย์จะอ่านโปรแกรมต้นฉบับนี้ได้ แต่คอมพิวเตอร์จะไม่เข้าใจคำสั่งเหล่านั้น จึงต้องมีการใช้ตัวแปลภาษาคอมพิวเตอร์ (Translator) ซึ่งจะประกอบไปด้วยรหัสคำสั่งที่คอมพิวเตอร์สามารถเข้าใจและนำไปปฏิบัติได้ ตัวแปลภาษาที่มีใช้ในปัจจุบันจะแตกต่างกัน สามารถแบ่งได้เป็น 2 แบบ ได้แก่

# %% [markdown]
# 1. คอมไพลเลอร์ (Compiler)
# เป็นตัวแปลภาษาที่ใช้หลักการแปลโปรแกรมต้นฉบับทั้งโปรแกรมและจะบันทึกไว้ในลักษณะของแฟ้มข้อมูลหรือไฟล์ เมื่อต้องการเรียกใช้งานโปรแกรมก็สามารถเรียกจากไฟล์มาใช้งาน โดยไม่ต้องทำการแปลอีก ทำให้การทำงานเป็นไปอย่างรวดเร็ว

# %% [markdown]
# ![111.png](data:image/png;base64,...)

# %% [markdown]
# 2. อินเทอร์พรีเตอร์ (Interpreter)
# เป็นตัวแปลภาษาที่จะแปลภาษาระดับสูง ที่ทำงานตามชุดคำสั่งที่เขียนไว้ทันที ซึ่งจะทำการแปลทีละคำสั่งแล้วให้คอมพิวเตอร์ทำตามคำสั่งนั้น เมื่อทำเสร็จแล้วจึงมาทำการแปลคำสั่งลำดับถัดไป จนจบโปรแกรม

# %% [markdown]
# ![5345.png](data:image/png;base64,...)

# %% [markdown]
# ## **🐍 รู้จักกับภาษาไพทอน**

# %% [markdown]
# ภาษาไพทอน (python) เป็นภาษาระดับสูง (High level Language) อยู่ในลักษณะของภาษาอินเทอร์พรีเตอร์โปรแกรมมิ่ง (Interpreter Programming) คือจะประมวลผลทีละบรรทัด
# ข้อดีของภาษาไพทอน
#
#
# *   เขียนง่าย เมื่อเทียบกับภาษาคอมพิวเตอร์ส่วนใหญ่แล้ว ✅
# *   ต่อยอดง่าย ภาษาไพทอน มีไลบรารีให้ใช้งานมากมายช่วยให้การเขียนโปรแกรมใหม่ทำได้รวดเร็วขึ้น ✅
# *   มีผู้ใช้งานจำนวนมาก ทำให้มีกลุ่มผู้ใช้จำนวนมากที่พร้อมให้ความช่วยเหลือและตอบคำถามเมื่อมีปัญหา ✅

# %% [markdown]
# ## **🤔 สิ่งที่ควรรู้ก่อนการขียนโปรแกรมด้วยภาษาไพทอน**

# %% [markdown]
# **ไอดีอี ภาษาไพทอน (Python IDE)**

# %% [markdown]
# IDE ย่อมาจาก Integrated Development Environment คือ เครื่องมือที่ช่วยในการพัฒนาโปรแกรมโดยมีสิ่งอำนวยความสะดวกต่างๆ เช่น คำสั่ง Compile, Run, Debugger เช่น
#
#
# *   [Python IDE (IDLE Shell)](https://www.python.org/)
# *   [PyCharm](https://www.jetbrains.com/pycharm/)
# *   [Visual Studio Code](https://code.visualstudio.com/)
# *   [Google Colab](https://colab.research.google.com/?utm_source=scs-index)

# %% [markdown]
# ---

# %% [markdown]
# ## **💻 🐍 พื้นฐานการเขียนโปรแกรมด้วยภาษาไพทอน**

# %% [markdown]
# ## ***ค่าและชนิดของข้อมูล (Data Type)***
#
# *   ในภาษาไพธอน มีให้เลือกใช้งานหลากหลายเช่นเดียวกับภาษาโปรแกรมอื่น ๆ และชนิดข้อมูลแต่ละชนิดก็มีเป้าหมายในการใช้งานที่แตกต่างกัน ในภาษาไพธอน มีชนิดข้อมูลให้ใช้งานดังนี้
#
# ```
# ตารางสรุปชนิดของข้อมูลหลักๆ
# ชื่อย่อ	     ความหมาย	        ตัวอย่าง
# int	       จำนวนเต็ม	        12345
# float	     จำนวนจริง	        123.45
# bool	        บูล	         True / False
# str	       สายอักขระ	   '12345' / 'Hello'
# ```

# %% [markdown]
# **การตรวจสอบชนิดของข้อมูลด้วยฟังก์ชัน type()**

# %% [markdown]
# Try It ! ⌨

# %%
# int
print(type(100))
# float
print(type(50.8))
# bool
a = 10
b = 15
c = a == b
print(c)
# str
print(type('Hello'))
# Out:
# <class 'int'>
# <class 'float'>
# False
# <class 'str'>

# %% [markdown]
# =====================================================================

# %% [markdown]
# ***Python สามารถแสดงผลข้อมูลทางหน้าจอได้ด้วย คำสั่ง Print()***

# %% [markdown]
# เช่น

# %%
t = 150
print(t)
# Out:
# 150

# %% [markdown]
# Try It ! ⌨

# %%
# ลองใช้คำสั่ง Print() เพื่อแสดงผลค่าข้อมูลนักเรียนต้องการ
________________________

# %% [markdown]
# ## ***ตัวแปร (variable)***
#
#
# *   ชื่อที่กำหนดขึ้นสำหรับใช้เก็บค่าในหน่วยความจำ ตัวแปร จะมีชื่อ (identifier) สำหรับใช้ในการอ้างอิงถึงค่าข้อมูล ผู้เขียนโปรแกรมสามารถใช้คำสั่งกำหนดค่า (assignment statement) เพื่อใช้ในการกำหนดให้ตัวแปรมีค่าตามที่ต้องการ

# %% [markdown]
# เช่น

# %%
a =
b =
i =

# %% [markdown]
# Try It ! ⌨

# %%
# ลองกำหนดค่าข้อมูลให้กับตัวแปร var
num_ber1 = 10

# %% [markdown]
# =====================================================================

# %% [markdown]
# ***การตั้งชื่อตัวแปร***
#
#
# *   การตั้งชื่อตัวแปรที่ดีควรสื่อความหมายและไม่ซ้ำกับชื่อฟังก์ชันหรือคำสงวนต่าง ๆ
# *   ตัวพิมพ์เล็กและตัวพิมพ์ใหญ่คือคนละตัวกัน เช่น data กับ Data
# *   ตัวแปรที่สร้างขึ้นต้องไม่เว้นวรรคหรือมีช่องว่าง หากต้องการให้ตัวแปรอ่านง่ายอาจใช้เครื่องหมาย underscore (_) ในการเชื่อต่อคำ เช่น room_temp
# *   ห้ามใช้เครืองหมายดำเนินการต่าง ๆ เช่น +  - * / ในการตั้งชื่อตัวแปร
# *   ห้ามใช้สัญลักษณ์ เช่น $ # @ % ในการตั้งชื่อตัวแปร
# *   ไม่เริ่มต้นด้วยตัวเลข แต่สามารถใช้ตัวเลยในตำแหน่งอื่น ๆ ได้ เช่น
#      *   1test ไม่สามารถตั้งชื่อตัวแปร
#      *   test1 เป็นชื่อตัวแปรได้

# %% [markdown]
# คำสงวน (Reserve Words)  ของภาษาไพทอน มีดังนี้

# %% [markdown]
# ![1_BEuH51qtcLZmIFxlbi5SpQ.png](data:image/png;base64,...)

# %% [markdown]
# Try It ! ⌨

# %%
# ลองตั้งชื่อตัวแปลเพื่อมาเก็บค่า "อายุ"
Age = 34

# %% [markdown]
# =====================================================================

# %% [markdown]
# =====================================================================

# %% [markdown]
# ## ***นิพจน์และตัวดำเนินการ***
#
# *   นิพจน์ (expression) ในภาษาไพทอน ได้แก่ ค่าของข้อมูลหรือค่าคงตัว (literal) ตัวแปร หรือการรวมกลุ่มของสิ่งดังกล่าวกับ ตัวดำเนินการ (operator) ตัวดำเนิการมีหลายประเภท เช่น ตัวดำเนินการคณิตศาสตร์ ตัวดำเนินการเปรียบเทียบ และตัวดำเนินการตรรกะ

# %% [markdown]
# ตัวดำเนินการคณิตศาสตร์ (arithmetic operator)

# %% [markdown]
# ```
# ตัวดำเนินการ           ความหมาย               ตัวอย่าง
#    ()                 จัดกลุ่ม              (a - b) + c
#    **                 ยกกำลัง                r**2
#    *                   คูณ                  x * 60
#    /                   หาร                   9/3
#    //                หารปัดเศษ               7//5
#    %                 หารเอาเศษ               15%4
#    +                   บวก                  20+50
#    -                   ลบ                   75-25
# ```

# %% [markdown]
# Try It ! ⌨

# %%
# ลองใช้ตัวดำเนินการทางคณิตศาสตร์
print(10+10)
print((156-10) / (4*8))
print(5**2)
print(5670 // 1000)
print(2 % 3)
# Out:
# 20
# 4.5625
# 25
# 5
# 2

# %% [markdown]
# 🔑 ตัวดำเนินการคณิตศาสตร์มีลำดับความสำคัญที่ใช้ในการประมวลผล ถ้าหากในกรณีที่มีตัวดำเนินหลายตัวในนิพจน์เดียวกัน การตัดสินใจว่าตัวดำเนินการใดจะทำงาน ก่อน หรือ หลัง ขึ้นอยู่กับลำดับความสำคัญ โดยจะเรียงลำดับความสำคัญดังนี้
#
#
# ```
# 1.   (  )  จัดกลุ่ม มีความสำคัญสูงสุด
# 2.   ** ยกกำลัง มีความสำคัญรองลงมา
# 3.   * / // % คุณ หาร หารปัดเศษทิ้ง หารเอาเศษ มีความสำคัญเท่ากัน โดยจะกระทำตามลำดับจากซ้ายไปขวาในนิพจน์
# 4.   + -  บวก และลบ มีความสำคัญต่ำสุด โดยจะกระทำจากซ้ายไปขวาในนิพจน์
# ```

# %% [markdown]
# เช่น โจทย์บอกว่าให้หา ค่าเฉลี่ย ของ 58, 83, 43, 51, 63
#
#
# *  สูตร $\bar{x} = \frac{\sum x}{n} $

# %% [markdown]
# Try It ! ⌨

# %%
# ลองเขียนแบบให้โปรแกรมกำหนดลำดับความสำคัญเอง
print(58+83+43+51+63 / 5)
# Out:
# 247.6

# %%
# ลองเขียนแบบเรากำหนดลำดับความสำคัญเอง
print((58+83+43+51+63) / 5)
# Out:
# 59.6

# %% [markdown]
# 🤔 ทบทวนความรู้ ให้นักเรียนเขียนโปรแกรมหาพื้นที่สามเหลี่ยม โดยกำหนดค่า ความยาวฐาน = 7, ความสูง = 4

# %% [markdown]
# Try It ! ⌨

# %%
base = 7
height = 4
area = 1/2 * base * height
print("พื้นที่สามเหลี่ยมมีค่า = ", area , "ตารางเซนติเมตร")
# Out:
# พื้นที่สามเหลี่ยมมีค่า =  14.0 ตารางเซนติเมตร

# %% [markdown]
# 🤔 ทบทวนความรู้ ให้นักเรียนเขียนโปรแกรมหาพื้นที่วงกลม โดยกำหนดค่า รัศมี = 7

# %% [markdown]
# Try It ! ⌨

# %% [markdown]
# ===============================================================

# %% [markdown]
# ## ***สตริง (String)***
#
#
# *   การกำหนดข้อความในภาษาไพทอน ผู้เขียนโปรแกรมสามารถเลือกใช้เครื่องหมายอัญประกาศเดี่ยว (' ') หรือเครื่องหมายอัญประกาศคู่ (" ") ได้ตามความเหมาะสม

# %% [markdown]
# Try It ! ⌨

# %%
name = 'Jirayus'
lname = 'Arundechachai'
print(name, lname)
print(lname)
# Out:
# Jirayus Arundechachai
# Arundechachai

# %% [markdown]
# ***ใช้ตัวดำเนินการทางคณิตศาสตร์ กับ สตริง (String and Operators)***
#
#
# *   เราสามารถใช้ตัวดำเนินการทางคณิตศาสตร์ (+, *) กับ String ได้

# %% [markdown]
# เช่น

# %%
name = 'Jirayus'
lname = 'Arundechachai'
print(name * 3)
print(name + lname)
# Out:
# JirayusJirayusJirayus
# JirayusArundechachai

# %% [markdown]
# **การจัดรูปแบบโดยใช้ตัวดำเนินการ % (String Formatting Operator)**
#
#
# *   %d : แสดงตัวเลขแบบไม่มีทศนิยม
# *   %f : แสดงตัวเลขแบบมีทศนิยม
# *   %s : แสดงข้อความ

# %% [markdown]
# Try It ! ⌨

# %%
name = 'Jirayus'
phone = 910570259
money = 589.75
print("สวัสดีครับผมชื่อ %s เบอร์โทรผมคือ %d และมีเงินอยู่ %.2f" %(name, phone, money))
# Out:
# สวัสดีครับผมชื่อ Jirayus เบอร์โทรผมคือ 910570259 และมีเงินอยู่ 589.75

# %% [markdown]
# =====================================================================

# %% [markdown]
# # ***บทที่ 4 การเขียนโปรแกรมเบื้องต้น (Part 2)*** 🍵

# %% [markdown]
# ### ***⏩ ตัวดำเนินการเปรียบเทียบ (Comparison operators)***

# %% [markdown]
# คือตัวดำเนินการที่ใช้สำหรับเปรียบเทียบค่าหรือค่าในตัวแปร ซึ่งผลลัพธ์ของการเปรียบเทียบนั้นจะเป็น True หากเงื่อนไขเป็นจริง และเป็น False หากเงื่อนไขไม่เป็นจริง ตัวดำเนินการเปรียบเทียบมักจะใช้กับคำสั่งตรวจสอบเงื่อนไข if และคำสั่งวนซ้ำ for while เพื่อควบคุมการทำงานของโปรแกรม
#
# ```
# ตัวดำเนินการ             ความหมาย            ตัวอย่าง
#    ==                   เท่ากัน              x == y
#    !=                  ไม่เท่ากัน             x != y
#    >=               มากกว่าหรือเท่ากับ         x >= y
#    <=               น้อยกว่าหรือเท่ากับ         x <= y
#    >                    มากกว่า             x > y
#    <                    น้อยกว่า             x < y
# ```

# %% [markdown]
# เช่น

# %% [markdown]
# ==============================================================================

# %% [markdown]
# ### ***🤑รูปแบบการเขียนนิพจน์แบบลดรูป (ตัวดำเนินการตามด้วยเครื่องหมาย = )***

# %% [markdown]
# ```
#       นิพจน์              ลดรูป                  ความหมาย
#     x = x + a           x += a         คำนวณค่า x + a เก็บไว้ที่ตัวแปร x
#     x = x - a           x -= a         คำนวณค่า x - a เก็บไว้ที่ตัวแปร x
#     x = x * a           x *= a         คำนวณค่า x * a เก็บไว้ที่ตัวแปร x
#     x = x / a           x /= a         คำนวณค่า x / a เก็บไว้ที่ตัวแปร x
#     x = x % a           x %= a         คำนวณค่า x % a เก็บไว้ที่ตัวแปร x
#     x = x ** a          x **= a        คำนวณค่า x ** a เก็บไว้ที่ตัวแปร x
# ```

# %% [markdown]
# เช่น

# %% [markdown]
# ==============================================================================

# %% [markdown]
# ### ***😝 การใส่คำอธิบาย (comment)***
# คอมเมนท์คือการเขียนบันทึกไว้เตือนความจำว่าคำสั่ง หรือส่วนของโปรแกรมทำงานอย่างไร โดยข้อความส่วนนี้จะไม่ถูกนำไปประมวลผล (Execute) การใส่ comment ทำได้  2 วิธี คือ
#
# 1.   เครื่องหมาย #  เช่น #This program is developed since May.22,2019
#
# 2.   เครื่องหมาย   '''.......''' คือ การใส่ comment ในรูปแบบหลายบรรทัด

# %% [markdown]
# เช่น

# %% [markdown]
# ==============================================================================

# %% [markdown]
# ### ***📺 คำสั่งการแสดงผลข้อมูลทางจอภาพ (เพิ่มเติม)***

# %% [markdown]
# **🖨รูปแบบการใช้งานฟังก์ชัน print()**
#
#
# ```
# print( value , … , sep = '  ' , end = '\n' )
#
# ```
# ฟังก์ชัน print() สามารถส่งอาร์กิวเมนต์ได้ตั้งแต่หนึ่งถึงหลายตัวเข้าไปในฟังก์ชัน และในฟังก์ชันจะมี
#
# *   อาร์กิวเมนต์ sep เป็นตัวแบ่ง ซึ่งมีค่า default เป็น whitespace (เว้นวรรค)
# *   อากิวเมนต์ end สำหรับแสดงผลในตอนท้าย ซึ่งมีค่า default เป็น \n หมายถึงการขึ้นบรรทัดใหม่
# *   การใช้ '....."...".....' เพื่อเน้นคำ

# %% [markdown]
# เช่น

# %% [markdown]
# Try It ! ⌨

# %% [markdown]
# **📎 รูปแบบแสดงผลที่ใช้เมธอด  format()**

# %% [markdown]
# format() จะมีการใช้เครื่องหมาย { }  เพื่อแทนตำแหน่งที่ตัวแปรจะถูกแทนที่และสามารถให้คำสั่งการจัดรูปแบบได้อย่างละเอียด
#
# รูปแบบการใช้งานเมธอด format()
#
# ```
# string.format(value1, value2…)
# ```
# การใช้ string.format เพื่อแสดงจุดทศนิยม
#
#
# ```
# {:.2f}
# ```
# การใช้ string.format เพื่อใส่คอมม่า(,) คั่นตัวเลข
#
# ```
# {:,}
# ```

# %% [markdown]
# เช่น

# %% [markdown]
# Try It ! ⌨

# %% [markdown]
# =========================================================================

# %% [markdown]
# ### ***⌨คำสั่งการอ่านข้อมูลจากแป้นพิมพ์***

# %% [markdown]
# ⏩ คำสั่งที่ใช้ในการรับค่าคือคำสั่ง input( ) ซึ่งใช้รับค่าจากคีย์บอร์ดมาเก็บไว้ในรปูแบบสายอักขระ(string)
# ตัวอย่างที่  การใช้คำสั่ง input ในการรับข้อมูล
#
#
# ```
# x = input('ระบุค่า x :')  #รับค่ามาเก็บที่ตัวแปร x เป็นชนิดข้อมูล str
# ```

# %% [markdown]
# Try It ! ⌨

# %% [markdown]
# ⏩ หากต้องการให้รับค่าเป็นชนิดของมูลแบบจำนวนเต็ม (integer) หรือจำนวนจริง(float) สามารถใช้คำสั่งดังนี้
# ```
# num_1 = int(input('ระบุค่าตัวเลข :')   #รับค่ามาเก็บตัวแปร num เป็นชนิดข้อมูล จำนวนเต็ม
# num_2 = float(input('ระบุค่าตัวเลข :') #รับค่ามาเก็บตัวแปร float เป็นชนิดข้อมูล จำนวนจริง
#
# ```

# %% [markdown]
# Try It ! ⌨

# %% [markdown]
# =========================================================================

# %% [markdown]
# ### ***😉การแปลงชนิดของข้อมูล (type conversion)***

# %% [markdown]
# เนื่องจากภาษาไพทอนมีความยืดหยุ่นในการแปลงชนิดข้อมูล ดังนั้นเราจึงสามารถจัดการแปลงข้อมูลได้ตามวัตถุประสงค์การใช้งาน
# ยกตัวอย่าง เช่น
#
#
# *   หากเรานำตัวแปร ที่เก็บค่า str จำนวนสองตัวแปร มา + กัน ผลลัพธ์ที่ได้จะเป็นการเชื่อมต่อสตริง
# * หากต้องการนำตัวแปร ทั้งสองมาคำนวณ จำเป็นต้องมีการแปลงชนิดข้อมูลจาก str ไปเป็น int ก่อน
#
# ดังตัวอย่าง

# %% [markdown]
# Try It ! ⌨

# %% [markdown]
# ---

# %% [markdown]
# Ex.จงรับข้อมูลเป็นตัวเลขจำนวน 4 หลัก แล้วคัดแยกเลขแต่ละตัวออกจากกัน โดยเริ่มจากซ้ายไปขวา
#
#
# ```
# ตัวอย่าง Output
# ระบุตัวเลข 4 หลัก : 2022
# 2
# 0
# 2
# 2
#
# ```
